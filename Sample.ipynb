# %% [markdown]
# <a href="https://colab.research.google.com/github/logambigaik/ALB-Ingress-Controller-Setup/blob/main/Sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python Day 1 -Data Analytics
### Hello world

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # Python Fundamental
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # hello world

# %% [markdown]
# # New section

# %%
print("Python')
# Out:
#   File "<ipython-input-20-c7f3dd43891f>", line 1
#     print("Python')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# Hello How are you?

# %%
pip install GitPython

# %%
import git

# Clone a repo
import git

# Clone the repository
# repo = git.Repo.clone_from("https://github.com/logambigaik/DataScience.git", "./DataScience")

# Navigate to the repo
# import os
# os.chdir("./DataScience")

# Add and commit the file
repo = git.Repo(".")
repo.index.add(["Sample.ipynb"])
repo.index.commit("Add file")

# Push the changes
origin = repo.remote(name='origin')
origin.push()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-6b411274c541> in <cell line: 0>()
#      13 # Add and commit the file
#      14 repo = git.Repo(".")
# ---> 15 repo.index.add(["Sample.ipynb"])
#      16 repo.index.commit("Add file")
#      17
#
# /usr/local/lib/python3.11/dist-packages/git/index/base.py in add(self, items, force, fprogress, path_rewriter, write, write_extension_data)
#     883         # If there are no paths, the rewriter has nothing to do either.
#     884         if paths:
# --> 885             entries_added.extend(self._entries_for_paths(paths, path_rewriter, fprogress, entries))
#     886
#     887         # HANDLE ENTRIES
#
# /usr/local/lib/python3.11/dist-packages/git/util.py in wrapper(self, *args, **kwargs)
#     174             raise InvalidGitRepositoryError("Method '%s' cannot operate on bare repositories" % func.__name__)
# ...

# %%
print("3.14")
# Out:
# 3.14

# %%
print(3.14)
print("hello\rworl\bd\bwelcome")
print("Hello","   ","world")
print("Hello"+"world")
print(30//11)
print(100 ** (1/2))

import math
x = math.sqrt(100);
print(x)
print(pow(100,1/2))
math.pow(100,1/2)
# !pip list
# Out:
# 3.14
# welcome
# Hello     world
# Helloworld
# 2
# 10.0
# 10.0
# 10.0
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.4.0
# accelerate                            1.7.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.11.15
# aiosignal                             1.3.2
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.7
# ale-py                                0.11.0
# altair                                5.5.0
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.9.0
# argon2-cffi                           23.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.2
# arviz                                 0.21.0
# ...

# %%
def do_we_stock_it():
    # Only change the code below this line
    in_stock = False
    description = 'This is a "lovely" ball of brown wool'
    amount = 4.5

    #
    amount = amount - 0.50                  # Reduce cost by 50p

    # Don't change the code below this line
    return [in_stock, description, amount]

print(do_we_stock_it())

x=33
y=30
x=y
print(x)

myName="Loga"
print(myName)
print(type(myName))
print(len(myName))
print(f'My name is {myName}, type is {type(myName)}, len is {len(myName)}')
print('My name is {} type {} len {}'.format(myName,type(myName),len(myName)))

age = input('Enter your age')
print(f"Your age is {int(age)+1}")
# Out:
# [False, 'This is a "lovely" ball of brown wool', 4.0]
# 30
# Loga
# <class 'str'>
# 4
# My name is Loga, type is <class 'str'>, len is 4
# My name is Loga type <class 'str'> len 4
# Enter your age20
# Your age is 21

# %%
num1= input("Enter first number")
num2 = input("Enter second number")
op= input("Enter any arithmetic operator (+, -, *, /):")
if(type(num1) =='float' and type(num2) =='float'):
  num1 = float(num1)
  num2 = float(num2)
else:
  num1=int(num1)
  num2=int(num2)

answer = f"{num1} {op} {num2}"

result =eval(answer)
print(f"{num1} {op} {num2} is {result}")


num1 = input("Enter first number: ")
num2 = input("Enter second number: ")
op = input("Enter any arithmetic operator (+, -, *, /): ")

# Try converting inputs
try:
    # Convert to float for safety; works for int or float input
    num1 = float(num1)
    num2 = float(num2)

    # Build and evaluate the expression
    answer = f"{num1} {op} {num2}"
    result = eval(answer)

    print(f"{num1} {op} {num2} is {result}")

except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
except ValueError:
    print("Error: Invalid number entered.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Enter first number20
# Enter second number10
# Enter any arithmetic operator (+, -, *, /):-
# 20 - 10 is 10
# Enter first number: 10
# Enter second number: 20
# Enter any arithmetic operator (+, -, *, /): +
# 10.0 + 20.0 is 30.0

# %%
pip install matplotlib.pyplot
# Out:
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot

# %%
pip install seaborn
# Out:
#   File "<ipython-input-7-a81ec5261f2d>", line 1
#     pip install seaborn,
#         ^
# SyntaxError: invalid syntax

# %%
from ast import increment_lineno
from os import ST_NOSUID
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style("whitegrid")
titanic =sns.load_dataset("titanic")
sns.jointplot(x='fare',y='age',data=titanic)

# %%
sns.distplot(titanic['fare'],color='red',kde=True, bins=30)
# Out:
# <ipython-input-23-d5fc2e03e9b3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['fare'],color='red',kde=True, bins=30)
# <Axes: xlabel='fare', ylabel='Density'>
